# %%
import pandas as pd
file_path = './2019_kbo_for_kaggle_v2.csv'
bb = pd.read_csv(file_path) # bb == baseball의 약자

# %%
# 문제 2-1-1. H, avg, HR, OBP의 TOP 10 player 출력
for i in range(2015,2019):
  bb_df = bb[(bb['year'] == i)]
  H = bb_df.sort_values(by='H', ascending=False).head(10)['batter_name'].tolist()
  avg = bb_df.sort_values(by='avg', ascending=False).head(10)['batter_name'].tolist()
  HR = bb_df.sort_values(by='HR', ascending=False).head(10)['batter_name'].tolist()
  OBP = bb_df.sort_values(by='OBP', ascending=False).head(10)['batter_name'].tolist()
  result = pd.DataFrame({'H' : H,'avg' : avg,'HR' : HR,'OBP' : OBP}, index = range(1, 11))
  print(f'{i} year Top10 player\n')
  print(result)
  print('\n')
# Out:
# 2015 year Top10 player
#
#       H  avg   HR  OBP
# 1   유한준  이진석  테임즈  이진석
# 2   나성범  테임즈  강민호  테임즈
# 3   테임즈  배영섭  최형우  김태균
# 4     필  유한준  최준석  배영섭
# 5   최형우  구자욱  나성범  박석민
# 6   이용규  채태인  이범호  유한준
# 7   아두치  마르테  아두치  최준석
# 8   이명기  박건우  박석민  이용규
# 9   박용택  이용규  황재균  안익훈
# 10  박민우  서상우  이승엽  강민호
#
#
# 2016 year Top10 player
#
#       H  avg    HR  OBP
# 1   최형우  권정웅    최정  권정웅
# 2   김태균  최원준   김재환  정진호
# 3   손아섭  김웅빈  로사리오  김태균
# 4   서건창  박광열   이범호  최형우
# 5   정의윤  나주환   박석민  최원준
# 6   정근우  최형우   최형우  김태완
# 7   나성범  정진호   정의윤  최재원
# 8   김주찬  박준혁   이승엽  신본기
# 9   박용택  김태균   오재일  나지완
# 10  고종욱  김선빈  히메네스  박준혁
#
#
# 2017 year Top10 player
#
#        H  avg    HR  OBP
# 1    손아섭  김선빈    최정  최형우
# 2    김재환  박건우  스크럭스  박민우
# 3    서건창  박민우   김재환  김재환
# 4    이정후  나성범   이대호   최정
# 5   버나디나  박용택    러프  박용택
# 6    박건우  최형우    로맥  박건우
# 7    김선빈  김태균   한동민  손아섭
# 8    최형우  김재환   나지완  김선빈
# 9    박용택  이상호  버나디나  나성범
# 10   구자욱  손아섭   최형우  김태균
#
#
# 2018 year Top10 player
#
#       H  avg   HR  OBP
# 1   전준우  안상현  김재환  최윤석
# 2   손아섭  유재신  로하스  유재신
# 3   이대호  양원혁  박병호  양원혁
# 4   최형우  장승현   로맥  안상현
# 5   나성범  전민재  한동민  박병호
# 6   김재환  정수빈  이대호  전병우
# 7   채은성  전병우   최정  국해성
# 8   최주환  김현수  이성열  정수빈
# 9   로하스  양의지  전준우  장승현
# 10  박해민   허일   러프  양의지

# %%
# 문제 2-1-2. war (승리 기여도)에 따른 가장 높은 값의 player 출력 by position (cp) in 2018. (15 points)
# 데이터 프레임의 열들을 이렇게 나열 - 포수, 1루수, 2루수, 3루수, 유격수, 좌익수, 중견수, 우익수

bb_df = bb[(bb['year'] == 2018)]
temp = ['포수', '1루수', '2루수', '3루수', '유격수', '좌익수', '중견수', '우익수']
value=[] # DataFrame의 batter_name list
index=[] # DataFrame의 cp list
war = bb_df.sort_values(by='war', ascending=False).head(30)['batter_name'].tolist()
cp = bb_df.sort_values(by='war', ascending=False).head(30)['cp'].tolist()
combine = list(zip(cp,war)) # war를 기준으로 내림차순하여 30위까지의 정보를 끌어와서 (cp,batter_name)으로 묶는다
for i,j in combine:
  if len(temp) != 0:
    if i in temp:
      index.append(i)
      value.append(j)
      temp.remove(i)
  else:
    break
result = pd.DataFrame({'war':value}, index = index)
result
# Out:
#      war
# 1루수  박병호
# 포수   양의지
# 좌익수  김재환
# 중견수  로하스
# 우익수  손아섭
# 2루수  최주환
# 유격수  김하성
# 3루수  허경민

# %%
# 문제 2-1-3. R(득점), H(안타), HR(홈런), RBI(타점), SB(도루), war(승리 기여도), avg(타율), OBP 중(출루율), SLG(장타율) 중 연봉(연봉)과 가장 상관관계가 높은 것은?
print(bb.corr()['salary'].sort_values(ascending=False)) # salary에 대한 상관관계 내림차순
# 결과를 보시면 salary에 대한 상관관계에서 가장 높은 값은 RBI(타점)에 있는 것을 볼 수 있다.
result = bb.corr()['salary'].sort_values(ascending=False)[1]
print(f'\nsalary와의 상관관계가 RBI가 {result}로 가장 높은 것을 알 수 있다.\n')
# Out:
# salary    1.000000
# RBI       0.547702
# HR        0.522212
# TB        0.520462
# age       0.497742
# FBP       0.495976
# BB        0.489863
# H         0.489694
# GDP       0.469555
# 2B        0.464104
# R         0.458858
# PA        0.458155
# GB        0.457962
# war       0.452117
# AB        0.452081
# 1B        0.452080
# SO        0.395812
# fly       0.394428
# G         0.372926
# YAB       0.371738
# HBP       0.348082
# SLG       0.331945
# OPS       0.327585
# YOPS      0.319282
# OBP       0.271342
# avg       0.263695
# p_year    0.241927
# year      0.241927
# CS        0.098169
# SB        0.079251
# 3B        0.050831
# BU       -0.070063
# Name: salary, dtype: float64
#
# salary와의 상관관계가 RBI가 0.5477024626375162로 가장 높은 것을 알 수 있다.
# <ipython-input-9-8c83e7d0e18b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(bb.corr()['salary'].sort_values(ascending=False)) # salary에 대한 상관관계 내림차순
# <ipython-input-9-8c83e7d0e18b>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   result = bb.corr()['salary'].sort_values(ascending=False)[1]
